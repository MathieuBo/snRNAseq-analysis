# %% [markdown]
# ## Analysis of RNA velocity
# Mathieu Bourdenx - Oct 2020

# %%
import velocyto as vcy

# %%
vlm = vcy.VelocytoLoom('./Mouse_PD_L2AKO_Cx_Hippo/loom/7221C.loom')

# %%
vlm.plot_fractions()

# %%
vlm.plot_expression_as_color(gene_name="Lamp2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-4a329517793a> in <module>
# ----> 1 vlm.plot_expression_as_color(gene_name="Lamp2")
#
# /opt/anaconda3/envs/velocyto/lib/python3.7/site-packages/velocyto/analysis.py in plot_expression_as_color(self, gene_name, imputed, cmap, gs, which_tsne, **kwargs)
#    2299             plt.subplot(gs)
#    2300
# -> 2301         tsne = getattr(self, which_tsne)
#    2302         if imputed:
#    2303             if self.which_S_for_pred == "Sx_sz":
#
# AttributeError: 'VelocytoLoom' object has no attribute 'ts'
